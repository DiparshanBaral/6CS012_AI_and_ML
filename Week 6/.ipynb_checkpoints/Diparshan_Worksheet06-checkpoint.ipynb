# %% [markdown]
# # Data Understanding and Visualizations.

# %% [markdown]
# ## 1. Import Required Libraries

# %%
# Import required libraries
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers, Sequential
from tensorflow.keras.utils import image_dataset_from_directory
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.applications import MobileNetV2
from sklearn.metrics import classification_report, confusion_matrix
from PIL import Image, UnidentifiedImageError
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import seaborn as sns

# Ensure reproducibility
tf.random.set_seed(42)
np.random.seed(42)

# Check TensorFlow version
print("TensorFlow version:", tf.__version__)
# Out:
# TensorFlow version: 2.18.0

# %% [markdown]
# ## 2. Dataset Preparation

# %% [markdown]
# ### 2.1 Verify Dataset Structure

# %%
# Define paths and parameters
train_dir = "./FruitinAmazon/train"
test_dir = "./FruitinAmazon/test"

img_size = (224, 224)
batch_size = 32

# Get class names
class_names = sorted(os.listdir(train_dir))
if not class_names:
    print("No class directories found in the train folder!")
else:
    print(f"Found {len(class_names)} classes: {class_names}")
# Out:
# Found 6 classes: ['acai', 'cupuacu', 'graviola', 'guarana', 'pupunha', 'tucuma']

# %% [markdown]
# ### 2.2 Check for Corrupted Images

# %%
from PIL import Image, UnidentifiedImageError

corrupted_images = []  # List to store corrupted image paths

# Loop through each class folder and check for corrupted images
for class_name in class_names:
    class_path = os.path.join(train_dir, class_name)
    if os.path.isdir(class_path):  # Ensure it’s a valid directory
        images = os.listdir(class_path)
        for img_name in images:
            img_path = os.path.join(class_path, img_name)
            try:
                with Image.open(img_path) as img:
                    img.verify()  # Verify image integrity
            except (IOError, UnidentifiedImageError):
                corrupted_images.append(img_path)

# Print results
if corrupted_images:
    print("\nCorrupted Images Found:")
    for img in corrupted_images:
        print(img)
else:
    print("\nNo corrupted images found.")
# Out:
# No corrupted images found.

# %% [markdown]
# ### 2.3 Count Class Balance

# %%
# Dictionary to store class counts
class_counts = {}

for class_name in class_names:
    class_path = os.path.join(train_dir, class_name)
    if os.path.isdir(class_path):
        images = [img for img in os.listdir(class_path) if img.lower().endswith(('.png', '.jpg', '.jpeg'))]
        class_counts[class_name] = len(images)  # Count images in each class

# Print class balance
print("\nClass Distribution:")
print("=" * 45)
print(f"{'Class Name':<25}{'Valid Image Count':>15}")
print("=" * 45)
for class_name, count in class_counts.items():
    print(f"{class_name:<25}{count:>15}")
print("=" * 45)
# Out:
# Class Distribution:
# =============================================
# Class Name               Valid Image Count
# =============================================
# acai                                  15
# cupuacu                               15
# graviola                              15
# guarana                               15
# pupunha                               15
# tucuma                                15
# =============================================

# %% [markdown]
# ### 2.4 Select Random Images for Visualization

# %%
import random

selected_images = []  # Store image paths
selected_labels = []  # Store corresponding class names

for class_name in class_names:
    class_path = os.path.join(train_dir, class_name)
    if os.path.isdir(class_path):
        images = [img for img in os.listdir(class_path) if img.lower().endswith(('.png', '.jpg', '.jpeg'))]
        if images:  # Ensure the class folder is not empty
            selected_img = os.path.join(class_path, random.choice(images))
            selected_images.append(selected_img)
            selected_labels.append(class_name)

# Display randomly selected images in a grid format
num_classes = len(selected_images)
cols = (num_classes + 1) // 2  # Determine columns
rows = 2  # Fixed rows for layout

fig, axes = plt.subplots(rows, cols, figsize=(12, 6))
for i, ax in enumerate(axes.flat):
    if i < num_classes:
        img = plt.imread(selected_images[i])
        ax.imshow(img)
        ax.set_title(selected_labels[i])
        ax.axis("off")
    else:
        ax.axis("off")  # Hide empty subplots
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 3. Data Generation and Preprocessing

# %% [markdown]
# ### 3.1 Generate Train and Validation Datasets

# %%
# Load datasets
train_ds = image_dataset_from_directory(
    train_dir,
    seed=1337,
    image_size=img_size,
    batch_size=batch_size,
)

test_ds = image_dataset_from_directory(
    test_dir,
    seed=1337,
    image_size=img_size,
    batch_size=batch_size,
)

# Prefetch datasets for better performance
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.prefetch(buffer_size=AUTOTUNE)
test_ds = test_ds.prefetch(buffer_size=AUTOTUNE)
# Out:
# Found 90 files belonging to 6 classes.
# Found 30 files belonging to 6 classes.

# %%
# Checking the shape of a batch
for images, labels in train_ds.take(1): # Take one batch
  print("Images shape:", images.shape)
  print("Labels shape:", labels.shape)
# Out:
# Images shape: (32, 224, 224, 3)
# Labels shape: (32,)

# %% [markdown]
# ### 3.2 Visualize Training Dataset

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(np.array(images[i]).astype("uint8"))
        plt.title(class_names[labels[i]])
        plt.axis("off")
plt.show()

# %% [markdown]
# ### 3.3 Data Augmentation

# %%
# Define the data augmentation layers
data_augmentation = Sequential([
    layers.RandomFlip("horizontal_and_vertical"),
    layers.RandomRotation(0.2),
    layers.RandomZoom(0.2),
    layers.RandomTranslation(0.2, 0.2),
    layers.RandomContrast(0.2),
    layers.RandomBrightness(0.2),
])

# %% [markdown]
# ### Visualize augmented images

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):  # Take 1 batch from original dataset
    augmented_images = data_augmentation(images)  # Apply augmentations
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(augmented_images[i].numpy().astype("uint8"))
        plt.axis("off")
    break
plt.show()

# %% [markdown]
# ## 4. Model Building

# %% [markdown]
# ### 4.1 Define the CNN Model

# %%
from tensorflow.keras.layers import (Lambda, Rescaling, Conv2D, BatchNormalization, Activation, MaxPooling2D, Dropout, Flatten, Dense, Input, GlobalAveragePooling2D)

# Define the model using the Sequential API with a list of layers
model = Sequential([
    # Define the input shape using InputLayer
    Input(shape=(224, 224, 3)),
    
    # Data Augmentation using Lambda
    Lambda(data_augmentation, input_shape=(224, 224, 3)),

    # Rescaling layer
    Rescaling(1./255),

    # First Convolutional Block
    Conv2D(32, (3, 3), padding='same', activation=None),
    BatchNormalization(),
    Activation('relu'),
    MaxPooling2D((2, 2)),
    Dropout(0.25),

    # Second Convolutional Block
    Conv2D(64, (3, 3), padding='same', activation=None),
    BatchNormalization(),
    Activation('relu'),
    MaxPooling2D((2, 2)),
    Dropout(0.25),

    # Third Convolutional Block
    Conv2D(128, (3, 3), padding='same', activation=None),
    BatchNormalization(),
    Activation('relu'),
    MaxPooling2D((2, 2)),
    Dropout(0.25),

    # Fourth Convolutional Block
    Conv2D(256, (3, 3), padding='same', activation=None),
    BatchNormalization(),
    Activation('relu'),
    MaxPooling2D((2, 2)),
    Dropout(0.25),

    # Flatten before fully connected layers
    Flatten(),

    # Fully Connected Layer 1
    Dense(512, activation=None),
    BatchNormalization(),
    Activation('relu'),
    Dropout(0.5),

    # Fully Connected Layer 2
    Dense(256, activation=None),
    BatchNormalization(),
    Activation('relu'),
    Dropout(0.5),

    # Fully Connected Layer 3
    Dense(128, activation=None),
    BatchNormalization(),
    Activation('relu'),
    Dropout(0.5),

    # Fully Connected Layer 4
    Dense(64, activation=None),
    BatchNormalization(),
    Activation('relu'),
    Dropout(0.5),

    # Output layer (10 classes)
    Dense(10, activation='softmax')
])

# Compile the model
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Model summary
model.summary()
# Out:
# C:\Users\ACER\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\core\lambda_layer.py:65: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lambda_3 (Lambda)                    │ (None, 224, 224, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ rescaling_3 (Rescaling)              │ (None, 224, 224, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_12 (Conv2D)                   │ (None, 224, 224, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_24               │ (None, 224, 224, 32)        │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_24 (Activation)           │ (None, 224, 224, 32)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_12 (MaxPooling2D)      │ (None, 112, 112, 32)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_24 (Dropout)                 │ (None, 112, 112, 32)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_13 (Conv2D)                   │ (None, 112, 112, 64)        │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_25               │ (None, 112, 112, 64)        │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_25 (Activation)           │ (None, 112, 112, 64)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_13 (MaxPooling2D)      │ (None, 56, 56, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_25 (Dropout)                 │ (None, 56, 56, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_14 (Conv2D)                   │ (None, 56, 56, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_26               │ (None, 56, 56, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_26 (Activation)           │ (None, 56, 56, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_14 (MaxPooling2D)      │ (None, 28, 28, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_26 (Dropout)                 │ (None, 28, 28, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_15 (Conv2D)                   │ (None, 28, 28, 256)         │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_27               │ (None, 28, 28, 256)         │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_27 (Activation)           │ (None, 28, 28, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_15 (MaxPooling2D)      │ (None, 14, 14, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_27 (Dropout)                 │ (None, 14, 14, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_3 (Flatten)                  │ (None, 50176)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_15 (Dense)                     │ (None, 512)                 │      25,690,624 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_28               │ (None, 512)                 │           2,048 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_28 (Activation)           │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_28 (Dropout)                 │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_16 (Dense)                     │ (None, 256)                 │         131,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_29               │ (None, 256)                 │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_29 (Activation)           │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_29 (Dropout)                 │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_17 (Dense)                     │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_30               │ (None, 128)                 │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_30 (Activation)           │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_30 (Dropout)                 │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_18 (Dense)                     │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_31               │ (None, 64)                  │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_31 (Activation)           │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_31 (Dropout)                 │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_19 (Dense)                     │ (None, 10)                  │             650 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 26,257,930 (100.17 MB)
#  Trainable params: 26,255,050 (100.16 MB)
#  Non-trainable params: 2,880 (11.25 KB)

# %% [markdown]
# ## 5. Training the Model

# %% [markdown]
# ### 5.1 Add Callbacks

# %%
# Define Early Stopping callback
early_stopping = EarlyStopping(
    monitor='val_loss',          # Monitor validation loss
    patience=10,                 # Wait for 10 epochs before stopping
    restore_best_weights=True   # Restore weights from the best epoch
)

# Define Learning Rate Reduction on Plateau callback
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',          # Monitor validation loss
    factor=0.5,                  # Reduce learning rate by a factor of 0.5
    patience=3,                  # Wait for 3 epochs before reducing LR
    min_lr=1e-6                  # Minimum learning rate
)

# %% [markdown]
# ## 5.2 Train the Model

# %%
# Train the model
history = model.fit(
    train_ds,
    validation_data=test_ds,     # Use test_ds for validation
    epochs=100,
    callbacks=[early_stopping, reduce_lr]
)
# Out:
# Epoch 1/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 8s 1s/step - accuracy: 0.0284 - loss: 3.4622 - val_accuracy: 0.0000e+00 - val_loss: 2.4543 - learning_rate: 0.0010
# Epoch 2/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.0568 - loss: 3.3203 - val_accuracy: 0.0000e+00 - val_loss: 2.3321 - learning_rate: 0.0010
# Epoch 3/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.0969 - loss: 2.8377 - val_accuracy: 0.0000e+00 - val_loss: 2.3498 - learning_rate: 0.0010
# Epoch 4/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.0991 - loss: 2.9355 - val_accuracy: 0.0000e+00 - val_loss: 2.3522 - learning_rate: 0.0010
# Epoch 5/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.0395 - loss: 3.1552 - val_accuracy: 0.0667 - val_loss: 2.3446 - learning_rate: 0.0010
# Epoch 6/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.0339 - loss: 2.9342 - val_accuracy: 0.0333 - val_loss: 2.3559 - learning_rate: 5.0000e-04
# Epoch 7/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.1152 - loss: 2.7620 - val_accuracy: 0.1000 - val_loss: 2.3494 - learning_rate: 5.0000e-04
# Epoch 8/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.0868 - loss: 2.9147 - val_accuracy: 0.1000 - val_loss: 2.3409 - learning_rate: 5.0000e-04
# Epoch 9/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.1337 - loss: 2.7801 - val_accuracy: 0.1667 - val_loss: 2.3338 - learning_rate: 2.5000e-04
# Epoch 10/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.1314 - loss: 2.6970 - val_accuracy: 0.1667 - val_loss: 2.3227 - learning_rate: 2.5000e-04
# Epoch 11/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.1905 - loss: 2.5125 - val_accuracy: 0.1667 - val_loss: 2.3087 - learning_rate: 2.5000e-04
# Epoch 12/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.1197 - loss: 2.8766 - val_accuracy: 0.1667 - val_loss: 2.2978 - learning_rate: 2.5000e-04
# Epoch 13/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.1526 - loss: 2.5005 - val_accuracy: 0.1667 - val_loss: 2.2923 - learning_rate: 2.5000e-04
# Epoch 14/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.1253 - loss: 2.5658 - val_accuracy: 0.1667 - val_loss: 2.2858 - learning_rate: 2.5000e-04
# Epoch 15/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.1715 - loss: 2.4858 - val_accuracy: 0.1667 - val_loss: 2.2807 - learning_rate: 2.5000e-04
# Epoch 16/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.1865 - loss: 2.4751 - val_accuracy: 0.1667 - val_loss: 2.2794 - learning_rate: 2.5000e-04
# Epoch 17/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.1905 - loss: 2.5305 - val_accuracy: 0.1667 - val_loss: 2.2766 - learning_rate: 2.5000e-04
# Epoch 18/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.1454 - loss: 2.6988 - val_accuracy: 0.1667 - val_loss: 2.2768 - learning_rate: 2.5000e-04
# Epoch 19/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.1709 - loss: 2.4478 - val_accuracy: 0.1667 - val_loss: 2.2763 - learning_rate: 2.5000e-04
# Epoch 20/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.1543 - loss: 2.6601 - val_accuracy: 0.1667 - val_loss: 2.2806 - learning_rate: 2.5000e-04
# Epoch 21/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.1820 - loss: 2.4275 - val_accuracy: 0.1667 - val_loss: 2.2867 - learning_rate: 2.5000e-04
# Epoch 22/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.1520 - loss: 2.4061 - val_accuracy: 0.1667 - val_loss: 2.2929 - learning_rate: 2.5000e-04
# Epoch 23/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.2556 - loss: 2.2642 - val_accuracy: 0.1667 - val_loss: 2.2967 - learning_rate: 1.2500e-04
# Epoch 24/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.1609 - loss: 2.4570 - val_accuracy: 0.1667 - val_loss: 2.2977 - learning_rate: 1.2500e-04
# Epoch 25/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.1526 - loss: 2.3678 - val_accuracy: 0.1667 - val_loss: 2.2981 - learning_rate: 1.2500e-04
# Epoch 26/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.1503 - loss: 2.4506 - val_accuracy: 0.1667 - val_loss: 2.2992 - learning_rate: 6.2500e-05
# Epoch 27/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.2244 - loss: 2.3790 - val_accuracy: 0.1667 - val_loss: 2.2986 - learning_rate: 6.2500e-05
# Epoch 28/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.1475 - loss: 2.4992 - val_accuracy: 0.1667 - val_loss: 2.2972 - learning_rate: 6.2500e-05
# Epoch 29/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.1609 - loss: 2.3790 - val_accuracy: 0.1667 - val_loss: 2.2988 - learning_rate: 3.1250e-05

# %% [markdown]
# ## 6. Evaluate the Model

# %% [markdown]
# ## 6.1 Plot Training History

# %%
plt.figure(figsize=(12, 4))

# Accuracy plot
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

# Loss plot
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %% [markdown]
# ## 6.2 Evaluate on Validation Dataset

# %%
# Evaluate the model
test_loss, test_acc = model.evaluate(val_ds)
print(f"Test Accuracy: {test_acc:.4f}")

# Extract all true labels from the validation dataset
true_labels = [label.numpy() for _, label in val_ds.unbatch()]  # Collect labels as a list
true_labels = np.array(true_labels)  # Convert the list to a NumPy array

# Generate predictions
predictions = model.predict(val_ds)
predicted_labels = np.argmax(predictions, axis=1)

# Print some predictions
for i in range(5):  # Print predictions for the first 5 samples
    print(f"Predicted: {class_names[predicted_labels[i]]}, Actual: {class_names[true_labels[i]]}")

# Confusion matrix
conf_matrix = confusion_matrix(true_labels, predicted_labels)
plt.figure(figsize=(10, 8))
plt.imshow(conf_matrix, cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.xticks(ticks=range(len(class_names)), labels=class_names, rotation=90)
plt.yticks(ticks=range(len(class_names)), labels=class_names)
plt.colorbar()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.0556 - loss: 2.4362
# Test Accuracy: 0.0556
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# Predicted: graviola, Actual: pupunha
# Predicted: graviola, Actual: pupunha
# Predicted: graviola, Actual: cupuacu
# Predicted: graviola, Actual: tucuma
# Predicted: graviola, Actual: cupuacu

# %% [markdown]
# ### Using Keras ImageDataGenerator (Old API)

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=40,
    zoom_range=0.3,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    brightness_range=[0.8, 1.2],
    horizontal_flip=True,
    fill_mode='nearest'
)

test_datagen = ImageDataGenerator(rescale=1./255)

# Load Data
train_data = train_datagen.flow_from_directory(train_dir, target_size=img_size, batch_size=batch_size, class_mode='categorical')
test_data = test_datagen.flow_from_directory(test_dir, target_size=img_size, batch_size=batch_size, class_mode='categorical', shuffle=False)

# Load Pretrained Model (MobileNetV2)
base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
base_model.trainable = False  # Freeze initial layers

# Define Model
model = tf.keras.Sequential([
    base_model,
    tf.keras.layers.GlobalAveragePooling2D(),
    tf.keras.layers.Dense(256, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.001)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(len(train_data.class_indices), activation='softmax')
])

# Compile Model
opt = tf.keras.optimizers.Adam(learning_rate=0.0001)
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

# Callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3)

# Train Model
history = model.fit(train_data, validation_data=test_data, epochs=70, callbacks=[early_stopping, lr_scheduler])

# Save the trained model
model.save("fruit_classification_model_v2.h5")

# Load the saved model
loaded_model = tf.keras.models.load_model("fruit_classification_model_v2.h5")

# Re-evaluate the model
y_true = test_data.classes
y_pred = np.argmax(loaded_model.predict(test_data), axis=1)
class_labels = list(test_data.class_indices.keys())

print("Re-evaluated Model Performance:")
print(classification_report(y_true, y_pred, target_names=class_labels))

# Confusion Matrix
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, cmap='Blues', xticklabels=class_labels, yticklabels=class_labels, fmt='d')
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# Plot Training Performance
plt.figure(figsize=(12,4))

# Accuracy Plot
plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.title("Accuracy Curve")

# Loss Plot
plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.legend()
plt.title("Loss Curve")

plt.show()
# Out:
# Found 90 images belonging to 6 classes.
# Found 30 images belonging to 6 classes.
# C:\Users\ACER\AppData\Roaming\Python\Python312\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - accuracy: 0.1859 - loss: 2.9609 - val_accuracy: 0.2000 - val_loss: 2.7260 - learning_rate: 1.0000e-04
# Epoch 2/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 509ms/step - accuracy: 0.2903 - loss: 2.8077 - val_accuracy: 0.2333 - val_loss: 2.5866 - learning_rate: 1.0000e-04
# Epoch 3/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 549ms/step - accuracy: 0.2643 - loss: 2.9638 - val_accuracy: 0.2333 - val_loss: 2.4458 - learning_rate: 1.0000e-04
# Epoch 4/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 503ms/step - accuracy: 0.3567 - loss: 2.5669 - val_accuracy: 0.2333 - val_loss: 2.3061 - learning_rate: 1.0000e-04
# Epoch 5/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 497ms/step - accuracy: 0.4073 - loss: 2.1907 - val_accuracy: 0.2333 - val_loss: 2.1816 - learning_rate: 1.0000e-04
# Epoch 6/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 507ms/step - accuracy: 0.3853 - loss: 2.3409 - val_accuracy: 0.2667 - val_loss: 2.0630 - learning_rate: 1.0000e-04
# Epoch 7/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 496ms/step - accuracy: 0.5496 - loss: 1.9748 - val_accuracy: 0.3667 - val_loss: 1.9519 - learning_rate: 1.0000e-04
# Epoch 8/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 551ms/step - accuracy: 0.6513 - loss: 1.5867 - val_accuracy: 0.4000 - val_loss: 1.8551 - learning_rate: 1.0000e-04
# Epoch 9/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 509ms/step - accuracy: 0.4901 - loss: 1.9897 - val_accuracy: 0.4667 - val_loss: 1.7685 - learning_rate: 1.0000e-04
# Epoch 10/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 497ms/step - accuracy: 0.4799 - loss: 1.8283 - val_accuracy: 0.5333 - val_loss: 1.6926 - learning_rate: 1.0000e-04
# Epoch 11/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 519ms/step - accuracy: 0.5806 - loss: 1.4752 - val_accuracy: 0.6000 - val_loss: 1.6235 - learning_rate: 1.0000e-04
# Epoch 12/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 510ms/step - accuracy: 0.6016 - loss: 1.5418 - val_accuracy: 0.6000 - val_loss: 1.5610 - learning_rate: 1.0000e-04
# Epoch 13/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 498ms/step - accuracy: 0.6604 - loss: 1.4840 - val_accuracy: 0.6000 - val_loss: 1.5025 - learning_rate: 1.0000e-04
# Epoch 14/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 502ms/step - accuracy: 0.6723 - loss: 1.3273 - val_accuracy: 0.6333 - val_loss: 1.4486 - learning_rate: 1.0000e-04
# Epoch 15/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 508ms/step - accuracy: 0.7506 - loss: 1.1150 - val_accuracy: 0.6667 - val_loss: 1.4002 - learning_rate: 1.0000e-04
# Epoch 16/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 509ms/step - accuracy: 0.7627 - loss: 1.1804 - val_accuracy: 0.6667 - val_loss: 1.3582 - learning_rate: 1.0000e-04
# Epoch 17/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 519ms/step - accuracy: 0.6955 - loss: 1.3965 - val_accuracy: 0.6667 - val_loss: 1.3197 - learning_rate: 1.0000e-04
# Epoch 18/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 509ms/step - accuracy: 0.8853 - loss: 0.8689 - val_accuracy: 0.6667 - val_loss: 1.2868 - learning_rate: 1.0000e-04
# Epoch 19/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 502ms/step - accuracy: 0.7967 - loss: 1.0642 - val_accuracy: 0.6667 - val_loss: 1.2583 - learning_rate: 1.0000e-04
# Epoch 20/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 501ms/step - accuracy: 0.8408 - loss: 1.0113 - val_accuracy: 0.6667 - val_loss: 1.2280 - learning_rate: 1.0000e-04
# Epoch 21/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 504ms/step - accuracy: 0.8818 - loss: 0.9483 - val_accuracy: 0.7000 - val_loss: 1.2006 - learning_rate: 1.0000e-04
# Epoch 22/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 552ms/step - accuracy: 0.8801 - loss: 0.9068 - val_accuracy: 0.7000 - val_loss: 1.1769 - learning_rate: 1.0000e-04
# Epoch 23/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 503ms/step - accuracy: 0.8001 - loss: 0.9357 - val_accuracy: 0.7000 - val_loss: 1.1516 - learning_rate: 1.0000e-04
# Epoch 24/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 507ms/step - accuracy: 0.8441 - loss: 0.8984 - val_accuracy: 0.7000 - val_loss: 1.1251 - learning_rate: 1.0000e-04
# Epoch 25/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 501ms/step - accuracy: 0.8102 - loss: 1.0794 - val_accuracy: 0.7000 - val_loss: 1.0996 - learning_rate: 1.0000e-04
# Epoch 26/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 507ms/step - accuracy: 0.7796 - loss: 0.9365 - val_accuracy: 0.7000 - val_loss: 1.0759 - learning_rate: 1.0000e-04
# Epoch 27/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 514ms/step - accuracy: 0.8281 - loss: 0.8722 - val_accuracy: 0.7000 - val_loss: 1.0556 - learning_rate: 1.0000e-04
# Epoch 28/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 504ms/step - accuracy: 0.8312 - loss: 0.9141 - val_accuracy: 0.7000 - val_loss: 1.0370 - learning_rate: 1.0000e-04
# Epoch 29/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 581ms/step - accuracy: 0.8159 - loss: 0.9083 - val_accuracy: 0.7000 - val_loss: 1.0178 - learning_rate: 1.0000e-04
# Epoch 30/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 545ms/step - accuracy: 0.8826 - loss: 0.8047 - val_accuracy: 0.7000 - val_loss: 1.0005 - learning_rate: 1.0000e-04
# Epoch 31/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 535ms/step - accuracy: 0.8702 - loss: 0.8315 - val_accuracy: 0.7333 - val_loss: 0.9838 - learning_rate: 1.0000e-04
# Epoch 32/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 551ms/step - accuracy: 0.8190 - loss: 0.9611 - val_accuracy: 0.7333 - val_loss: 0.9684 - learning_rate: 1.0000e-04
# Epoch 33/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 512ms/step - accuracy: 0.8984 - loss: 0.7592 - val_accuracy: 0.7667 - val_loss: 0.9551 - learning_rate: 1.0000e-04
# Epoch 34/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 574ms/step - accuracy: 0.8799 - loss: 0.6879 - val_accuracy: 0.7667 - val_loss: 0.9422 - learning_rate: 1.0000e-04
# Epoch 35/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 514ms/step - accuracy: 0.8686 - loss: 0.7910 - val_accuracy: 0.7667 - val_loss: 0.9294 - learning_rate: 1.0000e-04
# Epoch 36/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 562ms/step - accuracy: 0.9148 - loss: 0.7376 - val_accuracy: 0.8000 - val_loss: 0.9162 - learning_rate: 1.0000e-04
# Epoch 37/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 494ms/step - accuracy: 0.7705 - loss: 0.9099 - val_accuracy: 0.8000 - val_loss: 0.9046 - learning_rate: 1.0000e-04
# Epoch 38/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 571ms/step - accuracy: 0.8688 - loss: 0.7653 - val_accuracy: 0.8333 - val_loss: 0.8946 - learning_rate: 1.0000e-04
# Epoch 39/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 519ms/step - accuracy: 0.8826 - loss: 0.7673 - val_accuracy: 0.8333 - val_loss: 0.8854 - learning_rate: 1.0000e-04
# Epoch 40/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 555ms/step - accuracy: 0.9261 - loss: 0.7191 - val_accuracy: 0.8333 - val_loss: 0.8746 - learning_rate: 1.0000e-04
# Epoch 41/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 546ms/step - accuracy: 0.9394 - loss: 0.6506 - val_accuracy: 0.8333 - val_loss: 0.8629 - learning_rate: 1.0000e-04
# Epoch 42/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 539ms/step - accuracy: 0.8334 - loss: 0.8109 - val_accuracy: 0.8333 - val_loss: 0.8507 - learning_rate: 1.0000e-04
# Epoch 43/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 551ms/step - accuracy: 0.8427 - loss: 0.8056 - val_accuracy: 0.8667 - val_loss: 0.8406 - learning_rate: 1.0000e-04
# Epoch 44/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 517ms/step - accuracy: 0.9126 - loss: 0.7864 - val_accuracy: 0.8667 - val_loss: 0.8312 - learning_rate: 1.0000e-04
# Epoch 45/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 512ms/step - accuracy: 0.8992 - loss: 0.6690 - val_accuracy: 0.9000 - val_loss: 0.8207 - learning_rate: 1.0000e-04
# Epoch 46/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 551ms/step - accuracy: 0.9330 - loss: 0.6962 - val_accuracy: 0.9000 - val_loss: 0.8101 - learning_rate: 1.0000e-04
# Epoch 47/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 508ms/step - accuracy: 0.9381 - loss: 0.6447 - val_accuracy: 0.9000 - val_loss: 0.8034 - learning_rate: 1.0000e-04
# Epoch 48/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 514ms/step - accuracy: 0.9315 - loss: 0.6274 - val_accuracy: 0.9000 - val_loss: 0.7963 - learning_rate: 1.0000e-04
# Epoch 49/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 556ms/step - accuracy: 0.9358 - loss: 0.5919 - val_accuracy: 0.9000 - val_loss: 0.7897 - learning_rate: 1.0000e-04
# Epoch 50/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 552ms/step - accuracy: 0.9054 - loss: 0.6904 - val_accuracy: 0.9000 - val_loss: 0.7842 - learning_rate: 1.0000e-04
# Epoch 51/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 506ms/step - accuracy: 0.9109 - loss: 0.6063 - val_accuracy: 0.9000 - val_loss: 0.7776 - learning_rate: 1.0000e-04
# Epoch 52/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 506ms/step - accuracy: 0.9181 - loss: 0.6274 - val_accuracy: 0.9000 - val_loss: 0.7743 - learning_rate: 1.0000e-04
# Epoch 53/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 512ms/step - accuracy: 0.9613 - loss: 0.6042 - val_accuracy: 0.9000 - val_loss: 0.7716 - learning_rate: 1.0000e-04
# Epoch 54/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 506ms/step - accuracy: 0.9165 - loss: 0.6272 - val_accuracy: 0.9000 - val_loss: 0.7687 - learning_rate: 1.0000e-04
# Epoch 55/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 512ms/step - accuracy: 0.9272 - loss: 0.6483 - val_accuracy: 0.9000 - val_loss: 0.7650 - learning_rate: 1.0000e-04
# Epoch 56/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 557ms/step - accuracy: 0.9142 - loss: 0.7054 - val_accuracy: 0.9000 - val_loss: 0.7606 - learning_rate: 1.0000e-04
# Epoch 57/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 563ms/step - accuracy: 0.9570 - loss: 0.5722 - val_accuracy: 0.9000 - val_loss: 0.7573 - learning_rate: 1.0000e-04
# Epoch 58/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 591ms/step - accuracy: 0.9459 - loss: 0.6351 - val_accuracy: 0.9000 - val_loss: 0.7502 - learning_rate: 1.0000e-04
# Epoch 59/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 553ms/step - accuracy: 0.9358 - loss: 0.6267 - val_accuracy: 0.9000 - val_loss: 0.7455 - learning_rate: 1.0000e-04
# Epoch 60/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 557ms/step - accuracy: 0.8925 - loss: 0.6955 - val_accuracy: 0.9000 - val_loss: 0.7402 - learning_rate: 1.0000e-04
# Epoch 61/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 511ms/step - accuracy: 0.9504 - loss: 0.5629 - val_accuracy: 0.9000 - val_loss: 0.7356 - learning_rate: 1.0000e-04
# Epoch 62/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 517ms/step - accuracy: 0.9648 - loss: 0.5559 - val_accuracy: 0.9000 - val_loss: 0.7309 - learning_rate: 1.0000e-04
# Epoch 63/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 512ms/step - accuracy: 0.9716 - loss: 0.6582 - val_accuracy: 0.9333 - val_loss: 0.7251 - learning_rate: 1.0000e-04
# Epoch 64/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 503ms/step - accuracy: 0.9471 - loss: 0.5921 - val_accuracy: 0.9333 - val_loss: 0.7211 - learning_rate: 1.0000e-04
# Epoch 65/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 505ms/step - accuracy: 0.9613 - loss: 0.5799 - val_accuracy: 0.9333 - val_loss: 0.7172 - learning_rate: 1.0000e-04
# Epoch 66/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 502ms/step - accuracy: 0.9537 - loss: 0.5800 - val_accuracy: 0.9333 - val_loss: 0.7148 - learning_rate: 1.0000e-04
# Epoch 67/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 521ms/step - accuracy: 0.9459 - loss: 0.5713 - val_accuracy: 0.9333 - val_loss: 0.7123 - learning_rate: 1.0000e-04
# Epoch 68/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 505ms/step - accuracy: 0.9599 - loss: 0.5205 - val_accuracy: 0.9333 - val_loss: 0.7098 - learning_rate: 1.0000e-04
# Epoch 69/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 510ms/step - accuracy: 0.9889 - loss: 0.4967 - val_accuracy: 0.9333 - val_loss: 0.7074 - learning_rate: 1.0000e-04
# Epoch 70/70
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 510ms/step - accuracy: 0.9543 - loss: 0.5564 - val_accuracy: 0.9333 - val_loss: 0.7049 - learning_rate: 1.0000e-04
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:6 out of the last 38 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000002DA6C744CC0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 38 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000002DA6C744CC0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Re-evaluated Model Performance:
#               precision    recall  f1-score   support
#
#         acai       1.00      1.00      1.00         5
#      cupuacu       1.00      0.80      0.89         5
#     graviola       0.83      1.00      0.91         5
#      guarana       1.00      1.00      1.00         5
#      pupunha       1.00      0.80      0.89         5
#       tucuma       0.83      1.00      0.91         5
#
#     accuracy                           0.93        30
#    macro avg       0.94      0.93      0.93        30
# weighted avg       0.94      0.93      0.93        30

# %% [markdown]
# # Task 2: Transfer Learning with MobileNetV2

# %%
# Set image size compatible with MobileNetV2
IMAGE_SIZE = (128, 128)
BATCH_SIZE = 32

# Prepare ImageDataGenerators
train_ds = ImageDataGenerator(rescale=1./255)
val_ds = ImageDataGenerator(rescale=1./255)

# %%
train_gen = train_ds.flow_from_directory(
    './FruitinAmazon/train',
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical'
)

val_gen = val_ds.flow_from_directory(
    './FruitinAmazon/test',
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False
)
# Out:
# Found 90 images belonging to 6 classes.
# Found 30 images belonging to 6 classes.

# %% [markdown]
# ## 1. Load the base model

# %%
base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(128, 128, 3))

# Freeze all layers in the base model
for layer in base_model.layers:
    layer.trainable = False

# %% [markdown]
# ## 2. Add custom layers on top

# %%
from tensorflow.keras.models import Model

# Add custom layers on top
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dropout(0.5)(x)
x = Dense(128, activation='relu')(x)
predictions = Dense(train_gen.num_classes, activation='softmax')(x)

# Final model
model_tl = Model(inputs=base_model.input, outputs=predictions)

# Compile the model
model_tl.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ## 3. Train the model

# %%
history_tl = model_tl.fit(
    train_gen,
    validation_data=val_gen,
    epochs=5
)
# Out:
# Epoch 1/5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 637ms/step - accuracy: 0.1980 - loss: 2.7718 - val_accuracy: 0.3333 - val_loss: 1.7632
# Epoch 2/5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.4147 - loss: 1.4780 - val_accuracy: 0.5333 - val_loss: 1.2387
# Epoch 3/5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.6534 - loss: 0.7858 - val_accuracy: 0.7000 - val_loss: 0.8093
# Epoch 4/5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.7979 - loss: 0.5601 - val_accuracy: 0.8333 - val_loss: 0.6148
# Epoch 5/5
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.9299 - loss: 0.3279 - val_accuracy: 0.8000 - val_loss: 0.5261

# %% [markdown]
# ## 4. Evaluate model performance

# %%
val_loss_tl, val_acc_tl = model_tl.evaluate(val_gen)
print(f"Validation Accuracy: {val_acc_tl:.4f}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.8000 - loss: 0.5261
# Validation Accuracy: 0.8000

# %% [markdown]
# ## 5. Generate predictions and classification report

# %%
y_true = val_gen.classes
y_pred_probs = model_tl.predict(val_gen)
y_pred = np.argmax(y_pred_probs, axis=1)

# Classification Report
class_labels = list(val_gen.class_indices.keys())
report = classification_report(y_true, y_pred, target_names=class_labels)
print("\nClassification Report:\n")
print(report)

# Inference output (show first 10 predictions)
print("\nSample Inference Results:")
for i in range(10):
    print(f"True: {class_labels[y_true[i]]}, Predicted: {class_labels[y_pred[i]]}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 998ms/step
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#         acai       0.71      1.00      0.83         5
#      cupuacu       0.75      0.60      0.67         5
#     graviola       1.00      0.60      0.75         5
#      guarana       0.80      0.80      0.80         5
#      pupunha       0.83      1.00      0.91         5
#       tucuma       0.80      0.80      0.80         5
#
#     accuracy                           0.80        30
#    macro avg       0.82      0.80      0.79        30
# weighted avg       0.82      0.80      0.79        30
#
#
# Sample Inference Results:
# True: acai, Predicted: acai
# True: acai, Predicted: acai
# True: acai, Predicted: acai
# True: acai, Predicted: acai
# True: acai, Predicted: acai
# True: cupuacu, Predicted: cupuacu
# True: cupuacu, Predicted: cupuacu
# True: cupuacu, Predicted: cupuacu
# True: cupuacu, Predicted: acai
# True: cupuacu, Predicted: tucuma
